# %%
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
import warnings
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
warnings.filterwarnings("ignore")

# %%
train_audio_path = 'C:/Users/makar/Downloads/train/audio/'
samples, sample_rate = librosa.load(train_audio_path+'yes/0a7c2a8d_nohash_0.wav', sr = 16000)
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + '../input/train/audio/yes/0a7c2a8d_nohash_0.wav')
ax1.set_xlabel('time')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)

# %%
ipd.Audio(samples, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
labels=os.listdir(train_audio_path)

# %%
#find count of each label and plot bar graph
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()

# %%
labels=["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go"]

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings))
# Out:
# (array([1.5000e+01, 3.0000e+01, 4.4000e+01, 1.3800e+02, 1.3600e+02,
#         1.7900e+02, 3.6600e+02, 4.3400e+02, 5.9300e+02, 2.1747e+04]),
#  array([0.418 , 0.4762, 0.5344, 0.5926, 0.6508, 0.709 , 0.7672, 0.8254,
#         0.8836, 0.9418, 1.    ]),
#  <a list of 10 Patch objects>)

# %%
train_audio_path = 'C:/Users/makar/Downloads/train/audio/'

all_wave = []
all_label = []
for label in labels:
    print(label)
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000) : 
            all_wave.append(samples)
            all_label.append(label)
# Out:
# yes
# no
# up
# down
# left
# right
# on
# off
# stop
# go

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %%
from keras.utils import np_utils
y=np_utils.to_categorical(y, num_classes=len(labels))

# %%
all_wave = np.array(all_wave).reshape(-1,8000,1)

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.4,random_state=777,shuffle=True)

# %%
model = Sequential([
    Conv1D(8,13, padding='valid', activation='relu', strides=1,input_shape=(8000,1)),
    MaxPooling1D(3),
    Dropout(0.3),
    Conv1D(16, 11, padding='valid', activation='relu', strides=1),
    MaxPooling1D(3),
    Dropout(0.3),
    Conv1D(32, 9, padding='valid', activation='relu', strides=1),
    MaxPooling1D(3),
    Dropout(0.3),
    Conv1D(64, 7, padding='valid', activation='relu', strides=1),
    MaxPooling1D(3),
    Dropout(0.3),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(len(labels), activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_8 (Conv1D)            (None, 7988, 8)           112
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 2662, 8)           0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2662, 8)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 2652, 16)          1424
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 884, 16)           0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 884, 16)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 876, 32)           4640
# ...

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# Create Tensorflow checkpoint object
checkpoint_path = 'model_checkpoints/checkpoints'
mc = ModelCheckpoint(filepath=checkpoint_path,monitor='val_accuracy', verbose=1, save_best_only=True,frequency = 'epoch',mode='max')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001)

# %%
history=model.fit(x_tr, y_tr ,epochs=100, callbacks=[es,mc], batch_size=32, validation_data=(x_val,y_val))
# Out:
# Epoch 1/100
# 400/400 [==============================] - ETA: 0s - loss: 2.1229 - accuracy: 0.1936
# Epoch 00001: val_accuracy improved from -inf to 0.34029, saving model to model_checkpoints\checkpoints
# INFO:tensorflow:Assets written to: model_checkpoints\checkpoints\assets
# 400/400 [==============================] - 102s 255ms/step - loss: 2.1229 - accuracy: 0.1936 - val_loss: 1.8016 - val_accuracy: 0.3403
# Epoch 2/100
# 400/400 [==============================] - ETA: 0s - loss: 1.6285 - accuracy: 0.3980
# Epoch 00002: val_accuracy improved from 0.34029 to 0.49971, saving model to model_checkpoints\checkpoints
# INFO:tensorflow:Assets written to: model_checkpoints\checkpoints\assets
# 400/400 [==============================] - 105s 263ms/step - loss: 1.6285 - accuracy: 0.3980 - val_loss: 1.3969 - val_accuracy: 0.4997
# Epoch 3/100
# 400/400 [==============================] - ETA: 0s - loss: 1.3787 - accuracy: 0.4961
# ...

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from keras.models import load_model
model=load_model('model_checkpoints/checkpoints')

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]

# %%
import random
index=random.randint(0,len(x_val)-1)
samples=x_val[index].ravel()
print("Audio:",classes[np.argmax(y_val[index])])
ipd.Audio(samples, rate=8000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4fa7ae465379> in <module>
#       1 import random
# ----> 2 index=random.randint(0,len(x_val)-1)
#       3 samples=x_val[index].ravel()
#       4 print("Audio:",classes[np.argmax(y_val[index])])
#       5 ipd.Audio(samples, rate=8000)
#
# NameError: name 'x_val' is not defined

# %%
print("Text:",predict(samples))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5637a981cc7f> in <module>
# ----> 1 print("Text:",predict(samples))
#
# NameError: name 'predict' is not defined

# %%
from keras.models import load_model
model=load_model('model_checkpoints/checkpoints')

# %%
import sounddevice as sd
import soundfile as sf

samplerate = 16000  
duration = 1 # seconds
filename = 'yes.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)
# Out:
# start
# end

# %%
import os
os.listdir('C:/Users/makar/Desktop/project_2')
# Out:
# ['.ipynb_checkpoints',
#  'best_model.hdf5',
#  'model_checkpoints',
#  'model_checkpoints1',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'yes.wav']

# %%
filepath='C:/Users/makar/Desktop/project_2'

# %%
# reading the voice commands
import os
import IPython.display as ipd
import librosa
samples, sample_rate = librosa.load(filepath + '/' + 'yes.wav', sr = 16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
predict(samples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fc56b78c638d> in <module>
# ----> 1 predict(samples)
#
# NameError: name 'predict' is not defined
